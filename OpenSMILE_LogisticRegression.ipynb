# %%
import numpy as np
import pandas as pd
from os import listdir
import matplotlib.pyplot as plt
import itertools as it
from statsmodels.sandbox.stats.multicomp import multipletests
import statsmodels.api as sm
#import nltk
import scipy.stats as st
import statsmodels.formula.api as smf
import seaborn as sns
import Helper as hp

#Load Data
data = pd.read_csv("UIST2019_OpenSMILE.csv")

#Set Labels 
emotion_label = ['Anger', 'Boredom', 'Disgust', 'Fear', 'Happiness', 'Emo_Neutral', 'Sadness']
affect_label = ['Aggressiv', 'Cheerful', 'Intoxicated', 'Nervous', 'Aff_Neutral', 'Tired']
loi_label = ['Disinterest', 'Normal', 'High Interest']

#Get specific data and save it into new data frames
# We use the pandas .copy(deep=True) function to prevent the SettingWithCopyWarning we would otherwise get. Since we do
# not write, but only read from the data, the warning does not affect the data frames
df_emotion = data[['Anger', 'Boredom', 'Disgust', 'Fear', 'Happiness', 'Emo_Neutral', 'Sadness', 'Filename']].copy(deep=True)
df_affect = data[['Aggressiv', 'Cheerful', 'Intoxicated', 'Nervous', 'Aff_Neutral', 'Tired', 'Filename']].copy(deep=True)
df_loi = data[['Disinterest', 'Normal', 'High Interest', 'Filename']].copy(deep=True)
df_ar_val = data[['Arousal', 'Valence', 'Filename']].copy(deep=True)
#For further usage, we want to append the CharacterID as a column, which is saved with other information in the filename
#Since we only want the digits, we can remove all non-digit characters of the filename column and append the column to the df

df_emotion['Char_ID'] = df_emotion['Filename'].replace('\D+','', regex = True).copy(deep=True)
df_affect['Char_ID'] = df_affect['Filename'].replace('\D+','', regex = True).copy(deep=True)
df_loi['Char_ID'] = df_loi['Filename'].replace('\D+','', regex = True).copy(deep=True)
df_ar_val['Char_ID'] = df_ar_val['Filename'].replace('\D+','', regex = True).copy(deep=True)

#Load data about speakers
char_data = pd.read_csv("UIST2019_CharacterData.csv")  

#Join above tables and Character Tables

#To Join DataFrames we have to cast the column on which we want to join to int, so that both columns have the same data type
char_data['ID'] = char_data['ID'].astype(int)
df_ar_val['Char_ID'] = df_ar_val['Char_ID'].astype(int)
df_emotion['Char_ID'] = df_emotion['Char_ID'].astype(int)
df_affect['Char_ID'] = df_affect['Char_ID'].astype(int)
df_loi['Char_ID'] = df_loi['Char_ID'].astype(int)

#Safe new data frames
df_ar_val_char = df_ar_val.merge(char_data, how = 'left', left_on='Char_ID', right_on='ID')
df_emotion_char = df_emotion.merge(char_data, how = 'left', left_on='Char_ID', right_on= 'ID')
df_affect_char = df_affect.merge(char_data, how = 'left', left_on='Char_ID', right_on= 'ID')
df_loi_char = df_loi.merge(char_data, how = 'left', left_on='Char_ID', right_on= 'ID')

# %% [markdown]
# ## Let's start with the character feature 'sex'

# %%
# Let's prepare the datasets containing spaces for logistic regression
temp_emotion_char = df_emotion_char.rename(columns = {'Academic Status' : 'Academic'})
temp_affect_char = df_affect_char.rename(columns = {'Academic Status' : 'Academic'})
temp_loi_char = df_loi_char.rename(columns = {'Academic Status' : 'Academic', 'High Interest': 'High_Interest'})
temp_arval_char = df_ar_val_char.rename(columns = {'Academic Status' : 'Academic'})

# Start with model and sex
print('Emotion')
logreg_emo_sex = hp.multiLogReg(temp_emotion_char, 'Emotion', 'Sex',True) #boolean set prohibitWarnings to True
print(logreg_emo_sex.summary())
logreg_aff_sex = hp.multiLogReg(temp_affect_char, 'Affect', 'Sex', True)
print('Affect')
print(logreg_aff_sex.summary())
logreg_loi_sex = hp.multiLogReg(temp_loi_char, 'LOI', 'Sex', True) 
print('Level of Interest')
print(logreg_loi_sex.summary())
logreg_ar_val_sex = hp.multiLogReg(temp_arval_char, 'Arousal-Valence', 'Sex', True) # Yields LinAlgError: Singular Matrix
print('Arousal-Valence')
print(logreg_ar_val_sex.summary())
# Out:
# Emotion
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.366786
#          Iterations: 35
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    Sex   No. Observations:                  280
# Model:                          Logit   Df Residuals:                      272
# Method:                           MLE   Df Model:                            7
# Date:                Tue, 29 Sep 2020   Pseudo R-squ.:                  0.2440
# Time:                        13:37:52   Log-Likelihood:                -102.70
# converged:                      False   LL-Null:                       -135.85
#                                         LLR p-value:                 8.222e-12
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     655.7292   2.44e+05      0.003      0.998   -4.77e+05    4.78e+05
# Anger       -3490.1649   2.44e+05     -0.014      0.989   -4.81e+05    4.74e+05
# Boredom      -717.6207   2.44e+05     -0.003      0.998   -4.78e+05    4.77e+05
# Disgust      -649.9999   2.44e+05     -0.003      0.998   -4.78e+05    4.77e+05
# Fear          171.1523   2.44e+05      0.001      0.999   -4.77e+05    4.78e+05
# Happiness    4316.4627   2.43e+05      0.018      0.986   -4.73e+05    4.81e+05
# Emo_Neutral -1241.5924   2.44e+05     -0.005      0.996   -4.79e+05    4.76e+05
# Sadness      -657.7300   2.44e+05     -0.003      0.998   -4.78e+05    4.77e+05
# ===============================================================================
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.419493
#          Iterations: 35
# Affect
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    Sex   No. Observations:                  280
# Model:                          Logit   Df Residuals:                      273
# Method:                           MLE   Df Model:                            6
# Date:                Tue, 29 Sep 2020   Pseudo R-squ.:                  0.1354
# Time:                        13:37:52   Log-Likelihood:                -117.46
# converged:                      False   LL-Null:                       -135.85
#                                         LLR p-value:                 1.937e-06
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     271.4835   2.25e+05      0.001      0.999    -4.4e+05    4.41e+05
# Aggressiv    -251.0236   2.25e+05     -0.001      0.999   -4.41e+05     4.4e+05
# Cheerful     -277.8845   2.25e+05     -0.001      0.999   -4.41e+05     4.4e+05
# Intoxicated  -271.9686   2.25e+05     -0.001      0.999   -4.41e+05     4.4e+05
# Nervous      -275.3318   2.25e+05     -0.001      0.999   -4.41e+05     4.4e+05
# Aff_Neutral  -283.4047   2.25e+05     -0.001      0.999   -4.41e+05     4.4e+05
# Tired        -271.3755   2.25e+05     -0.001      0.999   -4.41e+05     4.4e+05
# ===============================================================================
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.462772
#          Iterations: 35
# Level of Interest
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    Sex   No. Observations:                  280
# Model:                          Logit   Df Residuals:                      276
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 29 Sep 2020   Pseudo R-squ.:                 0.04620
# Time:                        13:37:52   Log-Likelihood:                -129.58
# converged:                      False   LL-Null:                       -135.85
#                                         LLR p-value:                  0.005714
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      2149.6565   3.07e+05      0.007      0.994      -6e+05    6.04e+05
# Disinterest   -2155.4762   3.07e+05     -0.007      0.994   -6.04e+05       6e+05
# Normal        -2151.2519   3.07e+05     -0.007      0.994   -6.04e+05       6e+05
# High_Interest -2148.1227   3.07e+05     -0.007      0.994   -6.04e+05       6e+05
# =================================================================================
# Optimization terminated successfully.
#          Current function value: 0.396618
#          Iterations 7
# Arousal-Valence
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    Sex   No. Observations:                  280
# Model:                          Logit   Df Residuals:                      277
# Method:                           MLE   Df Model:                            2
# Date:                Tue, 29 Sep 2020   Pseudo R-squ.:                  0.1825
# Time:                        13:37:52   Log-Likelihood:                -111.05
# converged:                       True   LL-Null:                       -135.85
#                                         LLR p-value:                 1.698e-11
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.7387      0.262     -6.628      0.000      -2.253      -1.225
# Arousal       11.4502      1.845      6.206      0.000       7.834      15.066
# Valence       -6.6191      1.386     -4.775      0.000      -9.336      -3.902
# ==============================================================================
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %% [markdown]
# ### Character feature = age

# %%
logreg_emo_age = hp.multiNomiLogReg(temp_emotion_char, 'Emotion', 'Age', True)
print('Emotion:')
print(logreg_emo_age.summary())
logreg_aff_age = hp.multiNomiLogReg(temp_affect_char, 'Affect', 'Age', True)
print('Affect: ')
print(logreg_aff_age.summary())
logreg_loi_age = hp.multiNomiLogReg(temp_loi_char, 'LOI', 'Age', True)
print('Level of Interest: ')
print(logreg_loi_age.summary())
logreg_ar_val_age = hp.multiNomiLogReg(temp_arval_char, 'Arousal-Valence', 'Age', True)
print('Arousal-Valence:')
print(logreg_ar_val_age.summary())
temp_emotion_char
# Out:
# Optimization terminated successfully.
#          Current function value: nan
#          Iterations 7
# Emotion:
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  156
# Model:                        MNLogit   Df Residuals:                      140
# Method:                           MLE   Df Model:                           14
# Date:                Tue, 29 Sep 2020   Pseudo R-squ.:                     nan
# Time:                        13:38:03   Log-Likelihood:                    nan
# converged:                       True   LL-Null:                       -89.161
#                                         LLR p-value:                       nan
# ================================================================================
#   y=Age[Old]       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept           nan        nan        nan        nan         nan         nan
# Anger               nan        nan        nan        nan         nan         nan
# Boredom             nan        nan        nan        nan         nan         nan
# Disgust             nan        nan        nan        nan         nan         nan
# Fear                nan        nan        nan        nan         nan         nan
# Happiness           nan        nan        nan        nan         nan         nan
# Emo_Neutral         nan        nan        nan        nan         nan         nan
# Sadness             nan        nan        nan        nan         nan         nan
# --------------------------------------------------------------------------------
# y=Age[Young]       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept           nan        nan        nan        nan         nan         nan
# Anger               nan        nan        nan        nan         nan         nan
# Boredom             nan        nan        nan        nan         nan         nan
# Disgust             nan        nan        nan        nan         nan         nan
# Fear                nan        nan        nan        nan         nan         nan
# Happiness           nan        nan        nan        nan         nan         nan
# Emo_Neutral         nan        nan        nan        nan         nan         nan
# Sadness             nan        nan        nan        nan         nan         nan
# ================================================================================
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.549513
#          Iterations: 35
# Affect:
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  156
# Model:                        MNLogit   Df Residuals:                      142
# Method:                           MLE   Df Model:                           12
# Date:                Tue, 29 Sep 2020   Pseudo R-squ.:                 0.03855
# Time:                        13:38:03   Log-Likelihood:                -85.724
# converged:                      False   LL-Null:                       -89.161
#                                         LLR p-value:                    0.8658
# ================================================================================
#   y=Age[Old]       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     -311.7959   6.18e+05     -0.001      1.000   -1.21e+06    1.21e+06
# Aggressiv      303.4696   6.18e+05      0.000      1.000   -1.21e+06    1.21e+06
# Cheerful       317.5126   6.18e+05      0.001      1.000   -1.21e+06    1.21e+06
# Intoxicated    310.4660   6.18e+05      0.001      1.000   -1.21e+06    1.21e+06
# Nervous        309.3609   6.18e+05      0.001      1.000   -1.21e+06    1.21e+06
# Aff_Neutral    314.2192   6.18e+05      0.001      1.000   -1.21e+06    1.21e+06
# Tired          290.4062   6.18e+05      0.000      1.000   -1.21e+06    1.21e+06
# --------------------------------------------------------------------------------
# y=Age[Young]       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     -762.9138   3.27e+05     -0.002      0.998   -6.41e+05    6.39e+05
# Aggressiv      772.7688   3.27e+05      0.002      0.998   -6.39e+05    6.41e+05
# Cheerful       762.5680   3.27e+05      0.002      0.998   -6.39e+05    6.41e+05
# Intoxicated    764.6096   3.27e+05      0.002      0.998   -6.39e+05    6.41e+05
# Nervous        762.0768   3.27e+05      0.002      0.998   -6.39e+05    6.41e+05
# Aff_Neutral    766.1460   3.27e+05      0.002      0.998   -6.39e+05    6.41e+05
# Tired          763.0492   3.27e+05      0.002      0.998   -6.39e+05    6.41e+05
# ================================================================================
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.566953
#          Iterations: 35
# Level of Interest:
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  156
# Model:                        MNLogit   Df Residuals:                      148
# Method:                           MLE   Df Model:                            6
# Date:                Tue, 29 Sep 2020   Pseudo R-squ.:                0.008038
# Time:                        13:38:03   Log-Likelihood:                -88.445
# converged:                      False   LL-Null:                       -89.161
#                                         LLR p-value:                    0.9638
# =================================================================================
#    y=Age[Old]       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      1125.8504   8.67e+05      0.001      0.999    -1.7e+06     1.7e+06
# Disinterest   -1130.2842   8.67e+05     -0.001      0.999    -1.7e+06     1.7e+06
# Normal        -1126.6262   8.67e+05     -0.001      0.999    -1.7e+06     1.7e+06
# High_Interest -1128.2106   8.67e+05     -0.001      0.999    -1.7e+06     1.7e+06
# ---------------------------------------------------------------------------------
#  y=Age[Young]       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -2392.8466   4.62e+05     -0.005      0.996   -9.09e+05    9.04e+05
# Disinterest    2393.0275   4.62e+05      0.005      0.996   -9.04e+05    9.09e+05
# Normal         2394.6280   4.62e+05      0.005      0.996   -9.04e+05    9.09e+05
# High_Interest  2396.2958   4.62e+05      0.005      0.996   -9.04e+05    9.09e+05
# =================================================================================
# Optimization terminated successfully.
#          Current function value: 0.558052
#          Iterations 7
# Arousal-Valence:
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  156
# Model:                        MNLogit   Df Residuals:                      150
# Method:                           MLE   Df Model:                            4
# Date:                Tue,
# 22    10_b_a.wav       10   10
# 23   110_a_q.wav      110  110
# 24   111_a_q.wav      111  111
# 25   112_a_q.wav      112  112
# 26   113_a_q.wav      113  113
# 27   114_a_a.wav      114  114
# 28   114_b_a.wav      114  114
# 29   115_a_q.wav      115  115
# ..           ...      ...  ...
# 250   80_a_a.wav       80   80
# 251   81_a_q.wav       81   81
# 252   82_a_a.wav       82   82
# 253   82_b_a.wav       82   82
# 254   82_c_a.wav       82   82
# 255   83_a_q.wav       83   83
# 256   84_a_q.wav       84   84
# 257   85_a_q.wav       85   85
# 258   86_a_a.wav       86   86
# 259   86_b_a.wav       86   86
# 260   87_a_q.wav       87   87
# 261   88_a_q.wav       88   88
# 262   89_a_a.wav       89   89
# 263    8_a_q.wav        8    8
# 264   90_a_q.wav       90   90
# 265   91_a_a.wav       91   91
# 266   92_a_q.wav       92   92
# 267   93_a_a.wav       93   93
# 268   93_b_a.wav       93   93
# 269   94_a_q.wav       94   94
# 270   95_a_q.wav       95   95
# 271   96_a_a.wav       96   96
# 272   96_b_a.wav       96   96
# 273   96_c_a.wav       96   96
# 274   97_a_q.wav       97   97
# 275   98_a_q.wav       98   98
# 276   98_b_q.wav       98   98
# 277   99_a_a.wav       99   99
# 278   99_b_a.wav       99   99
# 279    9_a_q.wav        9    9
#
#                                             VideoTitle  \
# 0    3D printed Fabric: Techniques for Design and 3...
# 1    3D printed Fabric: Techniques for Design and 3...
# 2    3D printed Fabric: Techniques for Design and 3...
# 3             Question in Optimizing Portrait Lighting
# 4             Question in Optimizing Portrait Lighting
# 5    Proxino: Enabling Prototyping of Virtual Circu...
# 6    Proxino: Enabling Prototyping of Virtual Circu...
# 7                                  Question in Proxino
# 8                                  Question in Proxino
# 9    PseudoBend: Producing Haptic Illusions of Stre...
# 10   PseudoBend: Producing Haptic Illusions of Stre...
# 11   PseudoBend: Producing Haptic Illusions of Stre...
# 12   PseudoBend: Producing Haptic Illusions of Stre...
# 13                              Question in PseudoBend
# 14                              Question in PseudoBend
# 15                              Question in PseudoBend
# 16                              Question in PseudoBend
# 17   Pull-Ups: Enhancing Suspension Activities in V...
# 18   Pull-Ups: Enhancing Suspension Activities in V...
# 19   Pull-Ups: Enhancing Suspension Activities in V...
# 20   Pull-Ups: Enhancing Suspension Activities in V...
# 21   Aero-Plane: Handheld Force-Feedback Device tha...
# 22   Aero-Plane: Handheld Force-Feedback Device tha...
# 23                                Question in Pull-Ups
# 24                                Question in Pull-Ups
# 25                                Question in Pull-Ups
# 26                                Question in Pull-Ups
# 27   PUMICE: Multi-Modal Agent that Learns Concepts...
# 28   PUMICE: Multi-Modal Agent that Learns Concepts...
# 29                                  Question in PUMICE
# ..                                                 ...
# 250  LEVIProps: Animating Levitated Optimized Fabri...
# 251                              Question in LEVIProps
# 252  LightAnchors: Appropriating Point Lights for S...
# 253  LightAnchors: Appropriating Point Lights for S...
# 254  LightAnchors: Appropriating Point Lights for S...
# 255                           Question in LightAnchors
# 256                           Question in LightAnchors
# 257                           Question in LightAnchors
# 258  Loki: Facilitating Remote Instruction of Physi...
# 259  Loki: Facilitating Remote Instruction of Physi...
# 260                                   Question in Loki
# 261                                   Question in Loki
# 262  Magical Hands: Mid-Air Hand Gestures for Anima...
# 263  Question in Accurate and Low Latency Sensing o...
# 264                          Question in Magical Hands
# 265  Mallard: Turn the Web into a Contextualized Pr...
# 266                                Question in Mallard
# 267  Mantis: A Scalable, Lightweight and accessible...
# 268  Mantis: A Scalable, Lightweight and accessible...
# 269                                 Question in Mantis
# 270                                 Question in Mantis
# 271  Morphlour: Personalized Flour-based Morphing F...
# 272  Morphlour: Personalized Flour-based Morphing F...
# 273  Morphlour: Personalized Flour-based Morphing F...
# 274                                 Question in M-Hair
# 275                                 Question in M-Hair
# 276                                 Question in M-Hair
# 277  Optimizing Portrait Lighting at Capture-Time U...
# 278  Optimizing Portrait Lighting at Capture-Time U...
# 279  Question in Accurate and Low Latency Sensing o...
#
#                        Name     Sex      Academic           Age      VideoID
# 0          Haruki Takahashi    Male           PhD         Young  z07keSZOkO8
# 1          Haruki Takahashi    Male           PhD         Young  z07keSZOkO8
# 2          Haruki Takahashi    Male           PhD         Young  z07keSZOkO8
# 3             Scott Klemmer    Male           PhD  Intermediate          NaN
# 4                       NaN    Male           NaN           NaN          NaN
# 5                 Te-Yen Wu    Male  Grad Student         Young  _Klvg8YSrJQ
# 6                 Te-Yen Wu    Male  Grad Student         Young  _Klvg8YSrJQ
# 7            Andrea Bianchi    Male           PhD  Intermediate          NaN
# 8                       NaN  Female           NaN           NaN          NaN
# 9             Seongkook Heo    Male           PhD  Intermediate  rCYeWPUcMZU
# 10            Seongkook Heo    Male           PhD  Intermediate  rCYeWPUcMZU
# 11            Seongkook Heo    Male           PhD  Intermediate  rCYeWPUcMZU
# 12            Seongkook Heo    Male           PhD  Intermediate  rCYeWPUcMZU
# 13                      NaN    Male           NaN           NaN          NaN
# 14                      NaN    Male           NaN           NaN          NaN
# 15                      NaN  Female           NaN           NaN          NaN
# 16                      NaN    Male           NaN           NaN          NaN
# 17               Liwei Chen    Male           PhD  Intermediate  F8yPlAL9_BU
# 18               Liwei Chen    Male           PhD  Intermediate  F8yPlAL9_BU
# 19               Liwei Chen    Male           PhD  Intermediate  F8yPlAL9_BU
# 20               Liwei Chen    Male           PhD  Intermediate  F8yPlAL9_BU
# 21              Seungwoo Je    Male  Grad Student         Young  ZlaXB0N3JFU
# 22              Seungwoo Je    Male  Grad Student         Young  ZlaXB0N3JFU
# 23                      NaN    Male           NaN           NaN          NaN
# 24                      NaN    Male           NaN           NaN          NaN
# 25                      NaN  Female           NaN           NaN          NaN
# 26                      NaN    Male           NaN           NaN          NaN
# 27          Toby Jia-Jun Li    Male  Grad Student         Young  KSFZ0paxbxc
# 28          Toby Jia-Jun Li    Male  Grad Student         Young  KSFZ0paxbxc
# 29                      NaN    Male           NaN           NaN          NaN
# ..                      ...     ...           ...           ...          ...
# 250          Rafael Morales    Male           PhD         Young  4Y5C8AZZd80
# 251              Lining Yao  Female           PhD         Young          NaN
# 252             Karan Ahuja    Male  Grad Student         Young  mf2fy-Om23g
# 253             Karan Ahuja    Male  Grad Student         Young  mf2fy-Om23g
# 254             Karan Ahuja    Male  Grad Student         Young  mf2fy-Om23g
# 255                     NaN    Male           NaN           NaN          NaN
# 256                     NaN    Male           NaN           NaN          NaN
# 257                     NaN    Male           NaN           NaN          NaN
# 258  Bala Thoravi Kumaravel    Male  Grad Student         Young  urGqP7FHpOE
# 259  Bala Thoravi Kumaravel    Male  Grad Student         Young  urGqP7FHpOE
# 260                     NaN    Male           NaN           NaN          NaN
# 261                     NaN    Male           NaN           NaN          NaN
# 262             Rahul Arora    Male  Grad Student         Young  fIHhm7Vrgwo
# 263                     NaN    Male           NaN           NaN          NaN
# 264                     NaN    Male           NaN           NaN          NaN
# 265             Xiong Zhang    Male  Grad Student         Young  kZwG6Ah9lek
# 266                     NaN    Male           NaN           NaN          NaN
# 267          Gareth Barnaby    Male  Grad Student         Young  wm2j9xQOWIU
# 268          Gareth Barnaby    Male  Grad Student         Young  wm2j9xQOWIU
# 269                     NaN    Male           NaN           NaN          NaN
# 270                     NaN    Male           NaN           NaN          NaN
# 271           Humphrey Yang    Male  Grad Student         Young  8CrUvqvVQHI
# 272           Humphrey Yang    Male  Grad Student         Young  8CrUvqvVQHI
# 273           Humphrey Yang    Male  Grad Student         Young  8CrUvqvVQHI
# 274                     NaN    Male           NaN           NaN          NaN
# 275                     NaN    Male           NaN           NaN          NaN
# 276                     NaN    Male           NaN           NaN          NaN
# 277                  Jane E  Female  Grad Student         Young  W3miw6cYp80
# 278                  Jane E  Female  Grad Student         Young  W3miw6cYp80
# 279                     NaN    Male           NaN           NaN          NaN
#
# [280 rows x 16 columns]

# %% [markdown]
# ### Character feature = academic status

# %%
#logreg_emo_aca = hp.multiLogReg(temp_emotion_char, 'Emotion', 'Academic', True) # Raises LinAlg Singular Matrix Error
print('Emotions: ')
#print(logreg_emo_aca.summary())
logreg_aff_aca = hp.multiLogReg(temp_affect_char, 'Affect', 'Academic', True) 
print('Affect: ')
print(logreg_aff_aca.summary())
logreg_loi_aca = hp.multiLogReg(temp_loi_char, 'LOI', 'Academic', True)
print('Level of Interest: ')
print(logreg_loi_aca.summary())
logreg_ar_val_aca = hp.multiLogReg(temp_arval_char, 'Arousal-Valence', 'Academic', True)
print('Arousal-Valence: ')
print(logreg_ar_val_aca.summary())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1724: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-5-702622e017ad> in <module>()
# ----> 1 logreg_emo_aca = hp.multiLogReg(temp_emotion_char, 'Emotion', 'Academic', True)
#       2 print('Emotions: ')
#       3 print(logreg_emo_aca.summary())
#       4 logreg_aff_aca = hp.multiLogReg(temp_affect_char, 'Affect', 'Academic', True)
#       5 print('Affect: ')
#
# ~\Helper.py in multiLogReg(data, voice_feature, char_feature, prohibitWarning)
#     265         if(prohibitWarning == True):
#     266                 model.raise_on_perfect_prediction = False
# --> 267         res = model.fit()
#     268         return res
#     269
#
# ~\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    1832         bnryfit = super(Logit, self).fit(start_params=start_params,
#    1833                 method=method, maxiter=maxiter, full_output=full_output,
# -> 1834                 disp=disp, callback=callback, **kwargs)
#    1835
#    1836         discretefit = LogitResults(self, bnryfit)
#
# ~\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     218         mlefit = super(DiscreteModel, self).fit(start_params=start_params,
#     219                 method=method, maxiter=maxiter, full_output=full_output,
# --> 220                 disp=disp, callback=callback, **kwargs)
#     221
#     222         return mlefit # up to subclasses to wrap results
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     471             Hinv = cov_params_func(self, xopt, retvals)
#     472         elif method == 'newton' and full_output:
# --> 473             Hinv = np.linalg.inv(-retvals['Hessian']) / nobs
#     474         elif not skip_hessian:
#     475             H = -1 * self.hessian(xopt)
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in inv(a)
#     530     signature = 'D->D' if isComplexType(t) else 'd->d'
#     531     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 532     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     533     return wrap(ainv.astype(result_t, copy=False))
#     534
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_singular(err, flag)
#      87
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#      90
#      91 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
