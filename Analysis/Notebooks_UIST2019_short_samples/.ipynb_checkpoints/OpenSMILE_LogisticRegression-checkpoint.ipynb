# %%
import numpy as np
import pandas as pd
from os import listdir
import matplotlib.pyplot as plt
import itertools as it
from statsmodels.sandbox.stats.multicomp import multipletests
import statsmodels.api as sm
#import nltk
import scipy.stats as st
import statsmodels.formula.api as smf
import seaborn as sns
import Helper as hp

#Load Data
data = pd.read_csv("UIST_2019_short_samples_OpenSMILE.csv")

#Set Labels 
emotion_label = ['Anger', 'Boredom', 'Disgust', 'Fear', 'Happiness', 'Emo_Neutral', 'Sadness']
affect_label = ['Aggressiv', 'Cheerful', 'Intoxicated', 'Nervous', 'Aff_Neutral', 'Tired']
loi_label = ['Disinterest', 'Normal', 'High Interest']

#Get specific data and save it into new data frames
# We use the pandas .copy(deep=True) function to prevent the SettingWithCopyWarning we would otherwise get. Since we do
# not write, but only read from the data, the warning does not affect the data frames
df_emotion = data[['Anger', 'Boredom', 'Disgust', 'Fear', 'Happiness', 'Emo_Neutral', 'Sadness', 'Filename']].copy(deep=True)
df_affect = data[['Aggressiv', 'Cheerful', 'Intoxicated', 'Nervous', 'Aff_Neutral', 'Tired', 'Filename']].copy(deep=True)
df_loi = data[['Disinterest', 'Normal', 'High Interest', 'Filename']].copy(deep=True)
df_ar_val = data[['Arousal', 'Valence', 'Filename']].copy(deep=True)
#For further usage, we want to append the CharacterID as a column, which is saved with other information in the filename
#Since we only want the digits, we can remove all non-digit characters of the filename column and append the column to the df

df_emotion['Char_ID'] = df_emotion['Filename'].replace('\D+','', regex = True).copy(deep=True)
df_affect['Char_ID'] = df_affect['Filename'].replace('\D+','', regex = True).copy(deep=True)
df_loi['Char_ID'] = df_loi['Filename'].replace('\D+','', regex = True).copy(deep=True)
df_ar_val['Char_ID'] = df_ar_val['Filename'].replace('\D+','', regex = True).copy(deep=True)

#Load data about speakers
char_data = pd.read_csv("UIST2019_CharacterData.csv")  

#Join above tables and Character Tables

#To Join DataFrames we have to cast the column on which we want to join to int, so that both columns have the same data type
char_data['ID'] = char_data['ID'].astype(int)
df_ar_val['Char_ID'] = df_ar_val['Char_ID'].astype(int)
df_emotion['Char_ID'] = df_emotion['Char_ID'].astype(int)
df_affect['Char_ID'] = df_affect['Char_ID'].astype(int)
df_loi['Char_ID'] = df_loi['Char_ID'].astype(int)

#Safe new data frames
df_ar_val_char = df_ar_val.merge(char_data, how = 'left', left_on='Char_ID', right_on='ID')
df_emotion_char = df_emotion.merge(char_data, how = 'left', left_on='Char_ID', right_on= 'ID')
df_affect_char = df_affect.merge(char_data, how = 'left', left_on='Char_ID', right_on= 'ID')
df_loi_char = df_loi.merge(char_data, how = 'left', left_on='Char_ID', right_on= 'ID')

# %% [markdown]
# ## Let's start with the character feature 'sex'

# %%
# Let's prepare the datasets containing spaces for logistic regression
temp_emotion_char = df_emotion_char.rename(columns = {'Academic Status' : 'Academic'})
temp_affect_char = df_affect_char.rename(columns = {'Academic Status' : 'Academic'})
temp_loi_char = df_loi_char.rename(columns = {'Academic Status' : 'Academic', 'High Interest': 'High_Interest'})
temp_arval_char = df_ar_val_char.rename(columns = {'Academic Status' : 'Academic'})

# Start with model and sex
print('Emotion')
logreg_emo_sex = hp.multiLogReg(temp_emotion_char, 'Emotion', 'Sex',True) #boolean set prohibitWarnings to True
print(logreg_emo_sex.summary())
logreg_aff_sex = hp.multiLogReg(temp_affect_char, 'Affect', 'Sex', True)
print('Affect')
print(logreg_aff_sex.summary())
logreg_loi_sex = hp.multiLogReg(temp_loi_char, 'LOI', 'Sex', True) 
print('Level of Interest')
print(logreg_loi_sex.summary())
logreg_ar_val_sex = hp.multiLogReg(temp_arval_char, 'Arousal-Valence', 'Sex', True) # Yields LinAlgError: Singular Matrix
print('Arousal-Valence')
print(logreg_ar_val_sex.summary())
# Out:
# Emotion
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.385833
#          Iterations: 35
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    Sex   No. Observations:                  270
# Model:                          Logit   Df Residuals:                      262
# Method:                           MLE   Df Model:                            7
# Date:                Mon, 05 Oct 2020   Pseudo R-squ.:                  0.1948
# Time:                        15:12:31   Log-Likelihood:                -104.17
# converged:                      False   LL-Null:                       -129.37
#                                         LLR p-value:                 1.206e-08
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     166.6679   2.47e+05      0.001      0.999   -4.83e+05    4.83e+05
# Anger        -159.9849   2.47e+05     -0.001      0.999   -4.83e+05    4.83e+05
# Boredom      -168.6520   2.47e+05     -0.001      0.999   -4.83e+05    4.83e+05
# Disgust      -165.2815   2.47e+05     -0.001      0.999   -4.83e+05    4.83e+05
# Fear         -176.2953   2.47e+05     -0.001      0.999   -4.83e+05    4.83e+05
# Happiness    -120.5954   2.47e+05     -0.000      1.000   -4.83e+05    4.83e+05
# Emo_Neutral  -175.1935   2.47e+05     -0.001      0.999   -4.83e+05    4.83e+05
# Sadness      -169.0713   2.47e+05     -0.001      0.999   -4.83e+05    4.83e+05
# ===============================================================================
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.392976
#          Iterations: 35
# Affect
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    Sex   No. Observations:                  270
# Model:                          Logit   Df Residuals:                      263
# Method:                           MLE   Df Model:                            6
# Date:                Mon, 05 Oct 2020   Pseudo R-squ.:                  0.1799
# Time:                        15:12:31   Log-Likelihood:                -106.10
# converged:                      False   LL-Null:                       -129.37
#                                         LLR p-value:                 2.308e-08
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    -200.7601    2.4e+05     -0.001      0.999   -4.71e+05     4.7e+05
# Aggressiv     213.6259    2.4e+05      0.001      0.999    -4.7e+05    4.71e+05
# Cheerful      197.6598    2.4e+05      0.001      0.999    -4.7e+05    4.71e+05
# Intoxicated   201.1661    2.4e+05      0.001      0.999    -4.7e+05    4.71e+05
# Nervous       154.5671    2.4e+05      0.001      0.999    -4.7e+05    4.71e+05
# Aff_Neutral   192.5809    2.4e+05      0.001      0.999    -4.7e+05    4.71e+05
# Tired         201.8274    2.4e+05      0.001      0.999    -4.7e+05    4.71e+05
# ===============================================================================
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.451057
#          Iterations: 35
# Level of Interest
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    Sex   No. Observations:                  270
# Model:                          Logit   Df Residuals:                      266
# Method:                           MLE   Df Model:                            3
# Date:                Mon, 05 Oct 2020   Pseudo R-squ.:                 0.05866
# Time:                        15:12:31   Log-Likelihood:                -121.79
# converged:                      False   LL-Null:                       -129.37
#                                         LLR p-value:                  0.001670
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      -134.8271   3.43e+05     -0.000      1.000   -6.72e+05    6.72e+05
# Disinterest     101.5363   3.43e+05      0.000      1.000   -6.72e+05    6.72e+05
# Normal          133.3855   3.43e+05      0.000      1.000   -6.72e+05    6.72e+05
# High_Interest   136.5530   3.43e+05      0.000      1.000   -6.72e+05    6.72e+05
# =================================================================================
# Optimization terminated successfully.
#          Current function value: 0.400389
#          Iterations 7
# Arousal-Valence
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    Sex   No. Observations:                  270
# Model:                          Logit   Df Residuals:                      267
# Method:                           MLE   Df Model:                            2
# Date:                Mon, 05 Oct 2020   Pseudo R-squ.:                  0.1644
# Time:                        15:12:31   Log-Likelihood:                -108.11
# converged:                       True   LL-Null:                       -129.37
#                                         LLR p-value:                 5.790e-10
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.9060      0.207     -9.220      0.000      -2.311      -1.501
# Arousal       10.4640      2.025      5.167      0.000       6.495      14.433
# Valence       -7.6907      2.079     -3.700      0.000     -11.765      -3.617
# ==============================================================================
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %% [markdown]
# ### Character feature = age

# %%
logreg_emo_age = hp.multiNomiLogReg(temp_emotion_char, 'Emotion', 'Age', True)
print('Emotion:')
print(logreg_emo_age.summary())
logreg_aff_age = hp.multiNomiLogReg(temp_affect_char, 'Affect', 'Age', True)
print('Affect: ')
print(logreg_aff_age.summary())
logreg_loi_age = hp.multiNomiLogReg(temp_loi_char, 'LOI', 'Age', True)
print('Level of Interest: ')
print(logreg_loi_age.summary())
logreg_ar_val_age = hp.multiNomiLogReg(temp_arval_char, 'Arousal-Valence', 'Age', True)
print('Arousal-Valence:')
print(logreg_ar_val_age.summary())
temp_emotion_char
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.498333
#          Iterations: 35
# Emotion:
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  152
# Model:                        MNLogit   Df Residuals:                      136
# Method:                           MLE   Df Model:                           14
# Date:                Mon, 05 Oct 2020   Pseudo R-squ.:                  0.1427
# Time:                        15:12:31   Log-Likelihood:                -75.747
# converged:                      False   LL-Null:                       -88.359
#                                         LLR p-value:                   0.03242
# ================================================================================
#   y=Age[Old]       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     -177.0699   5.95e+05     -0.000      1.000   -1.17e+06    1.17e+06
# Anger          787.8090   5.95e+05      0.001      0.999   -1.17e+06    1.17e+06
# Boredom        214.1291   5.95e+05      0.000      1.000   -1.17e+06    1.17e+06
# Disgust        161.5903   5.95e+05      0.000      1.000   -1.17e+06    1.17e+06
# Fear           386.8458   5.95e+05      0.001      0.999   -1.17e+06    1.17e+06
# Happiness     -573.4404   5.95e+05     -0.001      0.999   -1.17e+06    1.17e+06
# Emo_Neutral     50.6056   5.95e+05    8.5e-05      1.000   -1.17e+06    1.17e+06
# Sadness        176.1711   5.95e+05      0.000      1.000   -1.17e+06    1.17e+06
# --------------------------------------------------------------------------------
# y=Age[Young]       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -1616.4493    3.3e+05     -0.005      0.996   -6.49e+05    6.46e+05
# Anger         2261.3853    3.3e+05      0.007      0.995   -6.45e+05     6.5e+05
# Boredom       1653.7322    3.3e+05      0.005      0.996   -6.46e+05    6.49e+05
# Disgust       1621.8555    3.3e+05      0.005      0.996   -6.46e+05    6.49e+05
# Fear          1930.1496    3.3e+05      0.006      0.995   -6.45e+05    6.49e+05
# Happiness      566.0320    3.3e+05      0.002      0.999   -6.47e+05    6.48e+05
# Emo_Neutral   1549.0435    3.3e+05      0.005      0.996   -6.46e+05    6.49e+05
# Sadness       1617.2773    3.3e+05      0.005      0.996   -6.46e+05    6.49e+05
# ================================================================================
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.491747
#          Iterations: 35
# Affect:
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  152
# Model:                        MNLogit   Df Residuals:                      138
# Method:                           MLE   Df Model:                           12
# Date:                Mon, 05 Oct 2020   Pseudo R-squ.:                  0.1541
# Time:                        15:12:31   Log-Likelihood:                -74.746
# converged:                      False   LL-Null:                       -88.359
#                                         LLR p-value:                  0.007169
# ================================================================================
#   y=Age[Old]       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept
# 255   91_a_a.wav       91   91
# 256   92_a_q.wav       92   92
# 257   93_a_a.wav       93   93
# 258   93_b_a.wav       93   93
# 259   94_a_q.wav       94   94
# 260   95_a_q.wav       95   95
# 261   96_a_a.wav       96   96
# 262   96_b_a.wav       96   96
# 263   96_c_a.wav       96   96
# 264   97_a_q.wav       97   97
# 265   98_a_q.wav       98   98
# 266   98_b_q.wav       98   98
# 267   99_a_a.wav       99   99
# 268   99_b_a.wav       99   99
# 269    9_a_q.wav        9    9
#
#                                             VideoTitle  \
# 0    3D printed Fabric: Techniques for Design and 3...
# 1    3D printed Fabric: Techniques for Design and 3...
# 2             Question in Optimizing Portrait Lighting
# 3             Question in Optimizing Portrait Lighting
# 4    Proxino: Enabling Prototyping of Virtual Circu...
# 5    Proxino: Enabling Prototyping of Virtual Circu...
# 6                                  Question in Proxino
# 7                                  Question in Proxino
# 8    PseudoBend: Producing Haptic Illusions of Stre...
# 9    PseudoBend: Producing Haptic Illusions of Stre...
# 10   PseudoBend: Producing Haptic Illusions of Stre...
# 11   PseudoBend: Producing Haptic Illusions of Stre...
# 12                              Question in PseudoBend
# 13                              Question in PseudoBend
# 14                              Question in PseudoBend
# 15                              Question in PseudoBend
# 16   Pull-Ups: Enhancing Suspension Activities in V...
# 17   Pull-Ups: Enhancing Suspension Activities in V...
# 18   Pull-Ups: Enhancing Suspension Activities in V...
# 19   Pull-Ups: Enhancing Suspension Activities in V...
# 20   Aero-Plane: Handheld Force-Feedback Device tha...
# 21   Aero-Plane: Handheld Force-Feedback Device tha...
# 22                                Question in Pull-Ups
# 23                                Question in Pull-Ups
# 24                                Question in Pull-Ups
# 25   PUMICE: Multi-Modal Agent that Learns Concepts...
# 26   PUMICE: Multi-Modal Agent that Learns Concepts...
# 27                                  Question in PUMICE
# 28                                  Question in PUMICE
# 29                                     Self-healing UI
# ..                                                 ...
# 240  LEVIProps: Animating Levitated Optimized Fabri...
# 241                              Question in LEVIProps
# 242  LightAnchors: Appropriating Point Lights for S...
# 243  LightAnchors: Appropriating Point Lights for S...
# 244  LightAnchors: Appropriating Point Lights for S...
# 245                           Question in LightAnchors
# 246                           Question in LightAnchors
# 247                           Question in LightAnchors
# 248  Loki: Facilitating Remote Instruction of Physi...
# 249  Loki: Facilitating Remote Instruction of Physi...
# 250                                   Question in Loki
# 251                                   Question in Loki
# 252  Magical Hands: Mid-Air Hand Gestures for Anima...
# 253  Question in Accurate and Low Latency Sensing o...
# 254                          Question in Magical Hands
# 255  Mallard: Turn the Web into a Contextualized Pr...
# 256                                Question in Mallard
# 257  Mantis: A Scalable, Lightweight and accessible...
# 258  Mantis: A Scalable, Lightweight and accessible...
# 259                                 Question in Mantis
# 260                                 Question in Mantis
# 261  Morphlour: Personalized Flour-based Morphing F...
# 262  Morphlour: Personalized Flour-based Morphing F...
# 263  Morphlour: Personalized Flour-based Morphing F...
# 264                              Question in Morphlour
# 265                              Question in Morphlour
# 266                              Question in Morphlour
# 262           Humphrey Yang    Male  Grad Student         Young  8CrUvqvVQHI
# 263           Humphrey Yang    Male  Grad Student         Young  8CrUvqvVQHI
# 264                     NaN    Male           NaN           NaN          NaN
# 265                     NaN    Male           NaN           NaN          NaN
# 266                     NaN    Male           NaN           NaN          NaN
# 267                  Jane E  Female  Grad Student         Young  W3miw6cYp80
# 268                  Jane E  Female  Grad Student         Young  W3miw6cYp80
# 269                     NaN    Male           NaN           NaN          NaN
#
#        IsNativeSpeaker
# 0     Asian Non-Native
# 1     Asian Non-Native
# 2       Native Speaker
# 3     Asian Non-Native
# 4     Asian Non-Native
# 5     Asian Non-Native
# 6    Europ. Non-Native
# 7       Native Speaker
# 8     Asian Non-Native
# 9     Asian Non-Native
# 10    Asian Non-Native
# 11    Asian Non-Native
# 12   Europ. Non-Native
# 13   Europ. Non-Native
# 14      Native Speaker
# 15   Europ. Non-Native
# 16    Asian Non-Native
# 17    Asian Non-Native
# 18    Asian Non-Native
# 19    Asian Non-Native
# 20    Asian Non-Native
# 21    Asian Non-Native
# 22    Asian Non-Native
# 23      Native Speaker
# 24      Native Speaker
# 25    Asian Non-Native
# 26    Asian Non-Native
# 27    Asian Non-Native
# 28    Asian Non-Native
# 29    Asian Non-Native
# ..                 ...
# 240  Europ. Non-Native
# 241   Asian Non-Native
# 242   Asian Non-Native
# 243   Asian Non-Native
# 244   Asian Non-Native
# 245     Native Speaker
# 246     Native Speaker
# 247   Asian Non-Native
# 248   Asian Non-Native
# 249   Asian Non-Native
# 250  Europ. Non-Native
# 251   Asian Non-Native
# 252   Asian Non-Native
# 253     Native Speaker
# 254   Asian Non-Native
# 255   Asian Non-Native
# 256     Native Speaker
# 257     Native Speaker
# 258     Native Speaker
# 259     Native Speaker
# 260  Europ. Non-Native
# 261   Asian Non-Native
# 262   Asian Non-Native
# 263   Asian Non-Native
# 264     Native Speaker
# 265   Asian Non-Native
# 266   Asian Non-Native
# 267     Native Speaker
# 268     Native Speaker
# 269   Asian Non-Native
#
# [270 rows x 17 columns]

# %% [markdown]
# ### Character feature = academic status

# %%
#logreg_emo_aca = hp.multiLogReg(temp_emotion_char, 'Emotion', 'Academic', True) # Raises LinAlg Singular Matrix Error
print('Emotions: ')
#print(logreg_emo_aca.summary())
logreg_aff_aca = hp.multiLogReg(temp_affect_char, 'Affect', 'Academic', True) 
print('Affect: ')
print(logreg_aff_aca.summary())
logreg_loi_aca = hp.multiLogReg(temp_loi_char, 'LOI', 'Academic', True)
print('Level of Interest: ')
print(logreg_loi_aca.summary())
logreg_ar_val_aca = hp.multiLogReg(temp_arval_char, 'Arousal-Valence', 'Academic', True)
print('Arousal-Valence: ')
print(logreg_ar_val_aca.summary())
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Emotions:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.586154
#          Iterations: 35
# Affect:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Academic   No. Observations:                  151
# Model:                          Logit   Df Residuals:                      144
# Method:                           MLE   Df Model:                            6
# Date:                Mon, 05 Oct 2020   Pseudo R-squ.:                 0.08967
# Time:                        15:12:31   Log-Likelihood:                -88.509
# converged:                      False   LL-Null:                       -97.228
#                                         LLR p-value:                  0.007805
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -1074.4551   2.38e+05     -0.005      0.996   -4.67e+05    4.65e+05
# Aggressiv    1063.8181   2.38e+05      0.004      0.996   -4.65e+05    4.67e+05
# Cheerful     1077.8321   2.38e+05      0.005      0.996   -4.65e+05    4.67e+05
# Intoxicated  1073.9849   2.38e+05      0.005      0.996   -4.65e+05    4.67e+05
# Nervous      1085.1781   2.38e+05      0.005      0.996   -4.65e+05    4.67e+05
# Aff_Neutral  1064.0086   2.38e+05      0.004      0.996   -4.65e+05    4.67e+05
# Tired        1073.7069   2.38e+05      0.005      0.996   -4.65e+05    4.67e+05
# ===============================================================================
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.624746
#          Iterations: 35
# Level of Interest:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Academic   No. Observations:                  151
# Model:                          Logit   Df Residuals:                      147
# Method:                           MLE   Df Model:                            3
# Date:                Mon, 05 Oct 2020   Pseudo R-squ.:                 0.02974
# Time:                        15:12:31   Log-Likelihood:                -94.337
# converged:                      False   LL-Null:                       -97.228
#                                         LLR p-value:                    0.1227
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -2427.4484    3.6e+05     -0.007      0.995   -7.09e+05    7.04e+05
# Disinterest    2469.3652    3.6e+05      0.007      0.995   -7.04e+05    7.09e+05
# Normal         2426.3326    3.6e+05      0.007      0.995   -7.04e+05    7.09e+05
# High_Interest  2425.4427    3.6e+05      0.007      0.995   -7.04e+05    7.09e+05
# =================================================================================
# Optimization terminated successfully.
#          Current function value: 0.593420
#          Iterations 6
# Arousal-Valence:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Academic   No. Observations:                  151
# Model:                          Logit   Df Residuals:                      148
# Method:                           MLE   Df Model:                            2
# Date:                Mon, 05 Oct 2020   Pseudo R-squ.:                 0.07839
# Time:                        15:12:31   Log-Likelihood:                -89.606
# converged:                       True   LL-Null:                       -97.228
#                                         LLR p-value:                 0.0004899
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3836      0.196     -1.960      0.050      -0.767   -7.63e-05
# Arousal       -8.3224      2.575     -3.232      0.001     -13.370      -3.275
# Valence        5.4008      2.367      2.282      0.022       0.762      10.040
# ==============================================================================

# %% [markdown]
# ### Native Speaker

# %%
#logreg_emo_aca = hp.multiLogReg(temp_emotion_char, 'Emotion', 'Academic', True) # Raises LinAlg Singular Matrix Error
print('Emotions: ')
#print(logreg_emo_aca.summary())
logreg_aff_aca = hp.multiNomiLogReg(temp_affect_char, 'Affect', 'IsNativeSpeaker', True) 
print('Affect: ')
print(logreg_aff_aca.summary())
logreg_loi_aca = hp.multiNomiLogReg(temp_loi_char, 'LOI', 'IsNativeSpeaker', True)
print('Level of Interest: ')
print(logreg_loi_aca.summary())
logreg_ar_val_aca = hp.multiNomiLogReg(temp_arval_char, 'Arousal-Valence', 'IsNativeSpeaker', True)
print('Arousal-Valence: ')
print(logreg_ar_val_aca.summary())
# Out:
# Emotions:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.947131
#          Iterations: 35
# Affect:
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  270
# Model:                        MNLogit   Df Residuals:                      256
# Method:                           MLE   Df Model:                           12
# Date:                Mon, 05 Oct 2020   Pseudo R-squ.:                 0.05450
# Time:                        15:12:31   Log-Likelihood:                -255.73
# converged:                      False   LL-Null:                       -270.47
#                                         LLR p-value:                  0.003339
# =====================================================================================================
# y=IsNativeSpeaker[Europ. Non-Native]       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept